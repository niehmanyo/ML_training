# %% [markdown]
# # Data Distribution

# %% [markdown]
# ## Uniform Distribution(均匀分布)
# <b>Uniform distributions are probability distributions with equally likely outcomes.</b>
# In a discrete uniform distribution, outcomes are discrete and have the same probability.
# In a continuous uniform distribution, outcomes are continuous and infinite.
# In a normal distribution, data around the mean occur more frequently.
# ![这是图片](./uniform_distribution.png)

# %%
import numpy as np
x = np.random.uniform(0.0,5.0,250) 
# create an array containing 250 random floats between 0 and 5

print(x)
# Out:
# [1.09861177 1.22314417 4.28645665 2.34256735 1.77308555 3.20488075
#  3.35037173 3.94881657 1.29193115 0.57530844 3.89199027 3.04621158
#  0.28618942 4.26207248 2.76222023 0.96244683 2.76632927 4.28616044
#  1.1493844  2.04972937 2.29275742 3.7433759  2.82114271 4.03790814
#  1.89480505 2.23526742 3.42302473 1.18987989 3.33110109 3.40853507
#  2.72197789 1.63933235 0.84770712 1.06565904 1.24838858 4.83990211
#  4.40644398 1.55760085 4.30635264 2.4733672  0.29808249 3.96826447
#  1.30238123 4.45374925 2.1915038  0.9516567  2.15586935 0.34611256
#  3.84548413 3.88742529 2.70521491 1.74055319 0.07909102 1.44020242
#  3.66150211 1.87805499 2.10157475 2.44749127 1.00914701 2.80136512
#  2.26312242 1.24717739 4.32653616 1.87297797 4.03995295 0.91271593
#  3.78016442 0.62385888 0.75548861 2.41623151 4.03743623 0.32417851
#  0.28920274 3.84033139 0.70965855 4.61505894 2.93000377 3.898208
#  1.30883244 2.06875245 0.32224243 1.34478149 0.94488412 4.66770096
# ...

# %% [markdown]
# ## Histogram (直方图📊)
#
# To visualize the data we collected.
# This is a function in *Python module Matplotlib*

# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.random.uniform(1.0,5.0,50)
plt.hist(x,10)
plt.show()
print(x)
# Out:
# [3.23049421 2.06389738 2.90761617 4.24882235 2.75076844 2.16597544
#  1.02505624 4.6150767  2.53043746 1.79413044 2.56495557 1.6185043
#  4.0948986  1.5638181  1.55516962 1.86051754 3.20916135 1.97951369
#  2.27336065 3.44604116 3.30323624 3.73240713 4.16650338 3.12749174
#  4.66619279 1.17010084 1.56214112 4.58730093 4.88570467 4.75492988
#  3.4818893  3.48289162 4.1318456  1.3201671  4.70358708 4.54273419
#  4.72649672 4.63914723 2.36094828 4.40946021 3.31668186 2.85037644
#  4.12162965 1.96757346 4.92508179 1.43791073 3.80608416 3.8723286
#  3.95200331 2.65941113]

# %% [markdown]
# ## Normal distribution (正态分布)

# %%
n = np.random.normal(1.0,5.0,1000)
plt.hist(n,25) # To create an histogram 创建直方图
plt.show()
